# %% [markdown]
# <a href="https://colab.research.google.com/github/PrismarineJS/mineflayer/blob/master/docs/mineflayer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using mineflayer in Python
#
# This is a tutorial on how to use mineflayer in Python. This example will connect you to the PrismarineJS test server. You can join it with prismarine-viewer or your Minecraft client at server IP **pjs.deptofcraft.com:25565**.
#
# If you're new to Jupyter Notebooks, you can press the "Play" button at the left of each code block to run it. Make sure that you run the blocks in a correct order.

# %% [markdown]
# ## Setup

# %% [markdown]
# First, make sure you have Python version 3.10 and Node.js version 18 or newer installed. You can get Node.js 18 it from https://nodejs.org/en/download or use [Node.js version managers](https://docs.npmjs.com/downloading-and-installing-node-js-and-npm#using-a-node-version-manager-to-install-nodejs-and-npm) like [`nvm`](https://github.com/creationix/nvm) or [`n`](https://github.com/tj/n) to install via the command line. Here we'll use `n` to install Node.js v18, then check our Node and Python versions:

# %%
# Use `n` to install nodejs 18, if it's not already installed:
# !curl -fsSL https://raw.githubusercontent.com/tj/n/master/bin/n | bash -s lts > /dev/null
# Now write the Node.js and Python version to the console
# !node --version
# !python --version
# Out:
# mkdir: /usr/local/n: Permission denied
#
#   Error: sudo required (or change ownership, or define N_PREFIX)
#
# zsh:1: command not found: node
# Python 3.9.19

# %% [markdown]
# Now, we can use pip to install the `javascript` Python package to access Node.js libraries from Python.

# %%
 # !pip install javascript
# Out:
# Requirement already satisfied: javascript in /Users/naem1023/miniforge3/envs/mw/lib/python3.9/site-packages (1!1.2.0)

# %% [markdown]
# ## Usage

# %% [markdown]
# If all is well, we can import the `javascript` library. We can then import the `require` function which works similarly to the `require` function in Node.js, but does the dependency management for us.
#
# You may notice the extra imports : On, Once, off and AsyncTask. These will be discussed later on.

# %%
from javascript import require, On, Once, AsyncTask, once, off
# Out:
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Users/naem1023/miniforge3/envs/mw/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/Users/naem1023/miniforge3/envs/mw/lib/python3.9/site-packages/ipykernel/ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "/Users/naem1023/miniforge3/envs/mw/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/naem1023/miniforge3/envs/mw/lib/python3.9/site-packages/javascript/connection.py", line 161, in com_io
#     raise e
#   File "/Users/naem1023/miniforge3/envs/mw/lib/python3.9/site-packages/javascript/connection.py", line 149, in com_io
#     proc = subprocess.Popen(
#   File "/Users/naem1023/miniforge3/envs/mw/lib/python3.9/subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/Users/naem1023/miniforge3/envs/mw/lib/python3.9/subprocess.py", line 1837, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'node'
# --====--	--====--
#
# Bridge failed to spawn JS process!
#
# Do you have Node.js 16 or newer installed? Get it at https://nodejs.org/
#
# --====--	--====--
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from javascript import require, On, Once, AsyncTask, once, off
#
# File ~/miniforge3/envs/mw/lib/python3.9/site-packages/javascript/__init__.py:27
#      23     if config.global_jsi.needsNodePatches():
#      24         config.node_emitter_patches = True
# ---> 27 init()
#      30 def terminate():
#      31     if config.event_loop:
#
# File ~/miniforge3/envs/mw/lib/python3.9/site-packages/javascript/__init__.py:18, in init()
#      16 config.executor = proxy.Executor(config.event_loop)
#      17 config.global_jsi = proxy.Proxy(config.executor, 0)
# ---> 18 console = config.global_jsi.console  # TODO: Remove this in 1.0
#      19 globalThis = config.global_jsi.globalThis
#      20 RegExp = config.global_jsi.RegExp
#
# File ~/miniforge3/envs/mw/lib/python3.9/site-packages/javascript/proxy.py:230, in Proxy.__getattr__(self, attr)
#     228 if attr == "new":
#     229     return self._call(self._pname if self._pffid == self.ffid else "", "class", self._pffid)
# --> 230 methodType, val = self._exe.getProp(self._pffid, attr)
#     231 return self._call(attr, methodType, val)
#
# File ~/miniforge3/envs/mw/lib/python3.9/site-packages/javascript/proxy.py:150, in Executor.getProp(self, ffid, method)
#     149 def getProp(self, ffid, method):
# --> 150     resp = self.ipc("get", ffid, method)
#     151     return resp["key"], resp["val"]
#
# File ~/miniforge3/envs/mw/lib/python3.9/site-packages/javascript/proxy.py:39, in Executor.ipc(self, action, ffid, attr, args)
#      36 else:
#      37     assert False, f"Unhandled action '{action}'"
# ---> 39 if not l.wait(10):
#      40     if not config.event_thread:
#      41         print(config.dead)
#
# File ~/miniforge3/envs/mw/lib/python3.9/threading.py:581, in Event.wait(self, timeout)
#     579 signaled = self._flag
#     580 if not signaled:
# --> 581     signaled = self._cond.wait(timeout)
#     582 return signaled
#
# File ~/miniforge3/envs/mw/lib/python3.9/threading.py:316, in Condition.wait(self, timeout)
#     314 else:
#     315     if timeout > 0:
# --> 316         gotit = waiter.acquire(True, timeout)
#     317     else:
#     318         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# We can now import Mineflayer

# %%
mineflayer = require('mineflayer')
pathfinder = require('mineflayer-pathfinder').pathfinder
Movements = require('mineflayer-pathfinder').Movements
goals = require('mineflayer-pathfinder')
# Out:
# Timed out get 0 require <Thread(Thread-7, started daemon 6285324288)>
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 mineflayer = require('mineflayer')
#       2 pathfinder = require('mineflayer-pathfinder').pathfinder
#       3 Movements = require('mineflayer-pathfinder').Movements
#
# File ~/miniforge3/envs/mw/lib/python3.9/site-packages/javascript/__init__.py:49, in require(name, version)
#      45     except Exception:
#      46         # On Notebooks, the frame info above does not exist, so assume the CWD as caller
#      47         calling_dir = os.getcwd()
# ---> 49 return config.global_jsi.require(name, version, calling_dir, timeout=900)
#
# File ~/miniforge3/envs/mw/lib/python3.9/site-packages/javascript/proxy.py:230, in Proxy.__getattr__(self, attr)
#     228 if attr == "new":
#     229     return self._call(self._pname if self._pffid == self.ffid else "", "class", self._pffid)
# --> 230 methodType, val = self._exe.getProp(self._pffid, attr)
#     231 return self._call(attr, methodType, val)
#
# File ~/miniforge3/envs/mw/lib/python3.9/site-packages/javascript/proxy.py:150, in Executor.getProp(self, ffid, method)
#     149 def getProp(self, ffid, method):
# --> 150     resp = self.ipc("get", ffid, method)
#     151     return resp["key"], resp["val"]
#
# File ~/miniforge3/envs/mw/lib/python3.9/site-packages/javascript/proxy.py:43, in Executor.ipc(self, action, ffid, attr, args)
#      41         print(config.dead)
#      42     print("Timed out", action, ffid, attr, repr(config.event_thread))
# ---> 43     raise Exception(f"Timed out accessing '{attr}'")
#      44 res, barrier = self.loop.responses[r]
#      45 del self.loop.responses[r]
#
# Exception: Timed out accessing 'require'

# %% [markdown]
# Once we've done that, we can create a new `bot` instance, through the `createBot` function. You can see the docs for this function [here](https://github.com/PrismarineJS/mineflayer/blob/master/docs/api.md#bot). In the line below we specify a hostname and a port for the server, but do not pass any `auth` or `password` options, so it will connect to the server in offline mode.
#
# Below that, we also a call to the `once` function, which pauses the thread until an event has been triggered, then returns the output. Here, we print out  "I spawned" after the `login` event has been triggered on `bot`.

# %%
random_number = id([]) % 1000 # Give us a random number upto 1000
BOT_USERNAME = f'hi_{random_number}'

bot = mineflayer.createBot({ 'host': 'localhost', 'port': 25565, 'username': BOT_USERNAME, 'hideErrors': False })

# The spawn event
once(bot, 'login')
bot.chat('I spawned')

# %% [markdown]
# If your bot spawned, we can now take a look at the bot's position

# %%
bot.entity.position
# Out:
# Vec3 { x: 70.5, y: 95, z: 158.5 }

# %% [markdown]
# ### Listening to events

# %% [markdown]
# You can register an event handler with the `@On` or `@Once` decorator. This decorator takes two arguments, first it's the **Event Emitter** (the object that is sending events) and the second is the **event name**, what event you want to listen to. *Do not use the .on or .once methods on bot, use the decorators instead.*
#
# A decorator always has a function under it which is being decorated, which can have any name. The first parameter to any event emitter callback is the `this` argument.
#
# In the code below, we create an event emitter on `bot` that listens to `playerJoin` events, then print that out.

# %%
@On(bot, 'playerJoin')
def end(this, player):
  bot.chat('Someone joined!')

# %% [markdown]
# In Python, you cannot leave any arguments for an event handler callback blank like in JavaScript. Instead, you can use the asterisk (`*`) operator in Python to capture all remaining arguments to the right, much like the `...` rest/spread operator in JavaScript. The parameter with the asterisk will be a tuple containing the captured arguments.
#
# You can stop listening for events through an event handler by using the imported `off` function. It takes three parameters: the emitter, event name, and a reference to the Python function.

# %%
@On(bot, 'chat')
def onChat(this, user, message, *rest):
  print(f'{user} said "{message}"')

  # If the message contains stop, remove the event listener and stop logging.
  if 'stop' in message:
    off(bot, 'chat', onChat)

# %% [markdown]
# You need to `off` all the event listeners you listen to with `@On`, else the Python process won't exit until all of the active event emitters have been off'ed. If you only need to listen once, you can use the `@Once` decroator like in the example above.

# %% [markdown]
# ## Asynchronous tasks
#
# By default, all the operations you do run on the main thread. This means you can only do one thing at a time. To multitask, you can use the `@AsyncTask` decroator to run a function in a new thread, while not obstructing the main thread.

# %% [markdown]
# ### Block breaking
#
# Take a look at the example below. Here we listen for a "break" trigger in a chat message, then we start digging the block underneath, while simultaneously sending a message that the bot has "started digging".

# %%
@On(bot, 'chat')
def breakListener(this, sender, message, *args):
  if sender and (sender != BOT_USERNAME):
    if 'break' in message:
      pos = bot.entity.position.offset(0, -1, 0)
      blockUnder = bot.blockAt(pos)
      if bot.canDigBlock(blockUnder):
        bot.chat(f"I'm breaking the '{blockUnder.name}' block underneath")
        # The start=True parameter means to immediately invoke the function underneath
        # If left blank, you can start it with the `start()` function later on.
        try:
          @AsyncTask(start=True)
          def break_block(task):
            bot.dig(blockUnder)
          bot.chat('I started digging!')
        except Exception as e:
          bot.chat(f"I had an error {e}")
      else:
        bot.chat(f"I can't break the '{blockUnder.name}' block underneath")
    if 'stop' in message:
      off(bot, 'chat', breakListener)

# %% [markdown]
# ## Using mineflayer plugins
#
# Pick the plugin you want from the list [here](https://github.com/PrismarineJS/mineflayer#third-party-plugins), then `require()` it and register it to the bot. Some plugins have different ways to register to the bot, look at the plugin's README for usage steps.

# %% [markdown]
# ### mineflayer-pathfinder
#
# `mineflayer-pathfinder` is a essential plugin that helps your bot move between places through A* pathfinding. Let's import it:

# %%
pathfinder = require('mineflayer-pathfinder')
bot.loadPlugin(pathfinder.pathfinder)
# Create a new minecraft-data instance with the bot's version
mcData = require('minecraft-data')(bot.version)
# Create a new movements class
movements = pathfinder.Movements(bot, mcData)
# How far to be from the goal
RANGE_GOAL = 1

# %% [markdown]
# Now let's have create a goal for the bot to move to where another player wants, based on a chat message.

# %%
bot.removeAllListeners('chat')
@On(bot, 'chat')
def handleMsg(this, sender, message, *args):
  if sender and (sender != BOT_USERNAME):
    bot.chat('Hi, you said ' + message)
    if 'come' in message:
      player = bot.players[sender]
      target = player.entity
      if not target:
        bot.chat("I don't see you !")
        return
      pos = target.position
      bot.pathfinder.setMovements(movements)
      bot.pathfinder.setGoal(pathfinder.goals.GoalNear(pos.x, pos.y, pos.z, RANGE_GOAL))
    if 'stop' in message:
      off(bot, 'chat', handleMsg)

# %%
bot.setControlState('jump', True)

# %% [markdown]
# ## Analyzing the world

# %% [markdown]
# You can also interact with mineflayer through any other Python package.

# %% [markdown]
# Let's analyze some block frequencies...

# %%
import matplotlib.pyplot as plt
figure = plt.figure()
axes = figure.add_axes([0,0,1,1])
Vec3 = require('vec3').Vec3

columns = bot.world.getColumns()
block_freqs = {}
for c in range(0, 3): # iterate through some of the loaded chunk columns
  cc = columns[c].column
  for y in range(1, 40):
    for x in range(1, 16):
      for z in range(1, 16):
        block = cc.getBlock(Vec3(x, y, z))
        if block.name in block_freqs:
          block_freqs[block.name] += 1
        else:
          block_freqs[block.name] = 1

print(block_freqs)
axes.bar(block_freqs.keys(), block_freqs.values())
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 figure = plt.figure()
#       3 axes = figure.add_axes([0,0,1,1])
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
bot_2 = mineflayer.createBot({ 'host': 'localhost', 'port': 25565, 'username': 'follow_bot', 'hideErrors': False })
bot_2.loadPlugin(pathfinder)
def followPlayer():
  player = bot_2.players['Steve']
  if not player:
    bot_2.chat("I don't see Steve!")
    return
  
  mcData = require('minecraft-data')(bot_2.version)
  movements = Movements(bot_2, mcData)

  bot_2.pathfinder.setMovements(movements)

  GoalFollow = goals.GoalFollow
  goal = GoalFollow(player.entity, 1)

bot_2.once('spawn', followPlayer)
# Out:
# EventEmitter {
#   _events: [Object: null prototype] {
#     error: [Function (anonymous)],
#     entitySleep: [Function (anonymous)],
#     entityWake: [Function (anonymous)],
#     messagestr: [Function (anonymous)],
#     death: [Function (anonymous)],
#     entityCrouch: [Function (anonymous)],
#     entityUncrouch: [Function (anonymous)],
#     spawn: [ [Function (anonymous)], [Function (anonymous)], [Function] ],
#     heldItemChanged: [Function (anonymous)],
#     newListener: [ [Function (anonymous)], [Function: listener] ],
#     move: [Function (anonymous)],
#     mount: [Function (anonymous)],
#     respawn: [Function (anonymous)],
#     login: [Function (anonymous)],
#     end: [Function: cleanup],
#     physicsTick: [Function: monitorMovement],
#     blockUpdate: [Function (anonymous)],
#     chunkColumnLoad: [Function (anonymous)],
#     removeListener: [Function: listenerRemove]
#   },
#   _eventsCount: 19,
#   _maxListeners: undefined,
#   _client: Client {
#     _events: [Object: null prototype] {
#       connect: [Array],
#       keep_alive: [Function: onKeepAlive],
#       end: [Array],
#       encryption_begin: [Function],
#       server_data: [Function (anonymous)],
#       login: [Array],
#       set_compression: [Function: onCompressionRequest],
#       login_plugin_request: [Function: onLoginPluginRequest],
#       custom_payload: [Function: onCustomPayload],
#       disconnect: [Array],
#       error: [Function (anonymous)],
#       connect_allowed: [Function: next],
#       game_state_change: [Array],
#       title: [Function (anonymous)],
#       block_action: [Function (anonymous)],
#       block_break_animation: [Function (anonymous)],
#       unload_chunk: [Function (anonymous)],
#       update_light: [Function (anonymous)],
#       chunk_batch_start: [Function (anonymous)],
#       chunk_batch_finished: [Function (anonymous)],
#       map_chunk: [Function (anonymous)],
#       map_chunk_bulk: [Function (anonymous)],
#       multi_block_change: [Function (anonymous)],
#       block_change: [Function (anonymous)],
#       explosion: [Array],
#       spawn_entity_painting: [Function (anonymous)],
#       entity_destroy: [Array],
#       update_sign: [Function (anonymous)],
#       tile_entity_data: [Function (anonymous)],
#       respawn: [Array],
#       boss_bar: [Function (anonymous)],
#       entity_metadata: [Array],
#       playerChat: [Function (anonymous)],
#       systemChat: [Function (anonymous)],
#       destroy_entity: [Function (anonymous)],
#       entity_equipment: [Function (anonymous)],
#       bed: [Function (anonymous)],
#       animation: [Function (anonymous)],
#       collect: [Function (anonymous)],
#       named_entity_spawn: [Function (anonymous)],
#       spawn_entity: [Array],
#       spawn_entity_experience_orb: [Function (anonymous)],
#       spawn_entity_living: [Function (anonymous)],
#       entity_velocity: [Function (anonymous)],
#       rel_entity_move: [Function (anonymous)],
#       entity_look: [Function (anonymous)],
#       entity_move_look: [Function (anonymous)],
#       entity_teleport: [Function (anonymous)],
#       entity_head_rotation: [Function (anonymous)],
#       entity_status: [Array],
#       attach_entity: [Array],
#       entity_effect: [Function (anonymous)],
#       remove_entity_effect: [Function (anonymous)],
#       update_attributes: [Function: updateAttributes],
#       entity_update_attributes: [Function: updateAttributes],
#       spawn_entity_weather: [Function (anonymous)],
#       player_info: [Array],
#       player_remove: [Array],
#       set_passengers: [Function (anonymous)],
#       experience: [Function (anonymous)],
#       world_particles: [Array],
#       registry_data: [Function (anonymous)],
#       difficulty: [Function (anonymous)],
#       'minecraft:brand': [Function (anonymous)],
#       ping: [Function (anonymous)],
#       update_health: [Array],
#       window_items: [Array],
#       set_slot: [Array],
#       set_cooldown: [Function (anonymous)],
#       transaction: [Function (anonymous)],
#       held_item_slot: [Function (anonymous)],
#       open_window: [Function (anonymous)],
#       open_horse_window: [Function (anonymous)],
#       close_window: [Function (anonymous)],
#       kick_disconnect: [Function (anonymous)],
#       position: [Function (anonymous)],
#       add_resource_pack: [Function (anonymous)],
#       remove_resource_pack: [Function (anonymous)],
#       resource_pack_send: [Function (anonymous)],
#       scoreboard_objective: [Function (anonymous)],
#       scoreboard_score: [Function (anonymous)],
#       scoreboard_display_objective: [Function (anonymous)],
#       teams: [Function: teamHandler],
#       named_sound_effect: [Function (anonymous)],
#       sound_effect: [Function (anonymous)],
#       spawn_position: [Function (anonymous)],
#       playerlist_header: [Function (anonymous)],
#       update_time: [Function (anonymous)],
#       profileless_chat: [Function (anonymous)],
#       system_chat: [Function (anonymous)],
#       message_header: [Function (anonymous)],
#       hide_message: [Function (anonymous)],
#       player_chat: [Function (anonymous)],
#       declare_commands: [Function (anonymous)],
#       chat_preview: [Function (anonymous)]
#     },
#     _eventsCount: 95,
#     _maxListeners: undefined,
#     customPackets: undefined,
#     version: '1.19.2',
#     isServer: false,
#     splitter: Splitter {
#       _readableState: [ReadableState],
#       _events: [Object: null prototype],
#       _eventsCount: 8,
#       _maxListeners: undefined,
#       _writableState: [WritableState],
#       allowHalfOpen: true,
#       buffer: <Buffer c5 4c b2 81 04 78 9c ed 7d 0f 74 5c d5 79 e7 bd 33 23 69 2c 64 e9 bd 91 4c 64 aa c5 ef 8d 64 1b 53 d2 48 33 ea c6 4e 00 8f 47 23 c7 61 59 b0 55 8d e0 ... 8629 more bytes>,
#       recognizeLegacyPing: false,
#       [Symbol(shapeMode)]: true,
#       [Symbol(kCapture)]: false,
#       [Symbol(kCallback)]: [Function: bound onwrite]
#     },
#     packetsToParse: {},
#     compressor: Compressor {
#       _readableState: [ReadableState],
#       _events: [Object: null prototype],
#       _eventsCount: 8,
#       _maxListeners: undefined,
#       _writableState: [WritableState],
#       allowHalfOpen: true,
#       compressionThreshold: 256,
#       [Symbol(shapeMode)]: true,
#       [Symbol(kCapture)]: false,
#       [Symbol(kCallback)]: null
#     },
#     framer: Framer {
#       _readableState: [ReadableState],
#       _events: [Object: null prototype],
#       _eventsCount: 7,
#       _maxListeners: undefined,
#       _writableState: [WritableState],
#       allowHalfOpen: true,
#       [Symbol(shapeMode)]: true,
#       [Symbol(kCapture)]: false,
#       [Symbol(kCallback)]: null
#     },
#     cipher: null,
#     decipher: null,
#     decompressor: Decompressor {
#       _readableState: [ReadableState],
#       _events: [Object: null prototype],
#       _eventsCount: 8,
#       _maxListeners: undefined,
#       _writableState: [WritableState],
#       allowHalfOpen: true,
#       compressionThreshold: 256,
#       hideErrors: false,
#       [Symbol(shapeMode)]: true,
#       [Symbol(kCapture)]: false,
#       [Symbol(kCallback)]: null
#     },
#     ended: false,
#     latency: 0,
#     hideErrors: false,
#     closeTimer: null,
#     protocolState: 'play',
#     serializer: Serializer {
#       _readableState: [ReadableState],
#       readable: true,
#       _events: [Object: null prototype],
#       _eventsCount: 4,
#       _maxListeners: undefined,
#       _writableState: [WritableState],
#       writable: true,
#       allowHalfOpen: true,
#       _transformState: [Object],
#       proto: [CompiledProtodef],
#       mainType: 'packet',
#       queue: <Buffer >,
#       [Symbol(shapeMode)]: true,
#       [Symbol(kCapture)]: false
#     },
#     deserializer: FullPacketParser {
#       _readableState: [ReadableState],
#       readable: true,
#       _events: [Object: null prototype],
#       _eventsCount: 7,
#       _maxListeners: undefined,
#       _writableState: [WritableState],
#       writable: true,
#       allowHalfOpen: true,
#       _transformState: [Object],
#       proto: [CompiledProtodef],
#       mainType: 'packet',
#       noErrorLogging: false,
#       [Symbol(shapeMode)]: true,
#       [Symbol(kCapture)]: false
#     },
#     _mcBundle: [],
#     _hasBundlePacket: true,
#     username: 'follow_bot',
#     uuid: 'c3d8700c-1e48-3e5a-9e0e-428d816d58cf',
#     socket: Socket {
#       connecting: false,
#       _hadError: false,
#       _parent: null,
#       _host: 'localhost',
#       _closeAfterHandlingError: false,
#       _events: [Object],
#       _readableState: [ReadableState],
#       _writableState: [WritableState],
#       allowHalfOpen: false,
#       _maxListeners: undefined,
#       _eventsCount: 8,
#       _sockname: null,
#       _pendingData: null,
#       _pendingEncoding: '',
#       server: null,
#       _server: null,
#       autoSelectFamilyAttemptedAddresses: [Array],
#       [Symbol(async_id_symbol)]: 75,
#       [Symbol(kHandle)]: [TCP],
#       [Symbol(lastWriteQueueSize)]: 0,
#       [Symbol(timeout)]: null,
#       [Symbol(kBuffer)]: null,
#       [Symbol(kBufferCb)]: null,
#       [Symbol(kBufferGen)]: null,
#       [Symbol(shapeMode)]: true,
#       [Symbol(kCapture)]: false,
#       [Symbol(kSetNoDelay)]: true,
#       [Symbol(kSetKeepAlive)]: false,
#       [Symbol(kSetKeepAliveInitialDelay)]: 0,
#       [Symbol(kBytesRead)]: 0,
#       [Symbol(kBytesWritten)]: 0
#     },
#     wait_connect: false,
#     serverFeatures: {},
#     registerChannel: [Function: registerChannel],
#     unregisterChannel: [Function: unregisterChannel],
#     writeChannel: [Function: writeChannel],
#     _players: {},
#     _lastChatSignature: null,
#     _lastRejectedMessage: null,
#     _lastSeenMessages: LastSeenMessages(0) [ capacity: 5, pending: 0 ],
#     _signatureCache: SignatureCache(0) [ capacity: 128, index: 0 ],
#     _lastChatHistory: [ capacity: 1024 ],
#     _signedChat: [Function (anonymous)],
#     signMessage: [Function (anonymous)],
#     verifyMessage: [Function (anonymous)],
#     reportPlayer: [Function (anonymous)],
#     chat: [Function (anonymous)],
#     [Symbol(shapeMode)]: false,
#     [Symbol(kCapture)]: false
#   },
#       '920': [Object],
#       '921': [Object],
#       '922': [Object],
#       '923': [Object],
#       '924': [Object],
#       '925': [Object],
#       '926': [Object],
#       '927': [Object],
#       '928': [Object],
#       '929': [Object],
#       '930': [Object],
#       '931': [Object],
#       '932': [Object]
#     },
#     blocksByName: {
#       air: [Object],
#       stone: [Object],
#       granite: [Object],
#       polished_granite: [Object],
#       diorite: [Object],
#       polished_diorite: [Object],
#       andesite: [Object],
#       polished_andesite: [Object],
#       grass_block: [Object],
#       dirt: [Object],
#       coarse_dirt: [Object],
#       podzol: [Object],
#       cobblestone: [Object],
#       oak_planks: [Object],
#       spruce_planks: [Object],
#       birch_planks: [Object],
#       jungle_planks: [Object],
#       acacia_planks: [Object],
#       dark_oak_planks: [Object],
#       mangrove_planks: [Object],
#       oak_sapling: [Object],
#       spruce_sapling: [Object],
#       birch_sapling: [Object],
#       jungle_sapling: [Object],
#       acacia_sapling: [Object],
#       dark_oak_sapling: [Object],
#       mangrove_propagule: [Object],
#       bedrock: [Object],
#       water: [Object],
#       lava: [Object],
#       sand: [Object],
#       red_sand: [Object],
#       gravel: [Object],
#       gold_ore: [Object],
#       deepslate_gold_ore: [Object],
#       iron_ore: [Object],
#       deepslate_iron_ore: [Object],
#       coal_ore: [Object],
#       deepslate_coal_ore: [Object],
#       nether_gold_ore: [Object],
#       oak_log: [Object],
#       spruce_log: [Object],
#       birch_log: [Object],
#       jungle_log: [Object],
#       acacia_log: [Object],
#       dark_oak_log: [Object],
#       mangrove_log: [Object],
#       mangrove_roots: [Object],
#       muddy_mangrove_roots: [Object],
#       stripped_spruce_log: [Object],
#       stripped_birch_log: [Object],
#       stripped_jungle_log: [Object],
#       stripped_acacia_log: [Object],
#       stripped_dark_oak_log: [Object],
#       stripped_oak_log: [Object],
#       stripped_mangrove_log: [Object],
#       oak_wood: [Object],
#       spruce_wood: [Object],
#       birch_wood: [Object],
#       jungle_wood: [Object],
#       acacia_wood: [Object],
#       dark_oak_wood: [Object],
#       mangrove_wood: [Object],
#       stripped_oak_wood: [Object],
#       stripped_spruce_wood: [Object],
#       stripped_birch_wood: [Object],
#       stripped_jungle_wood: [Object],
#       stripped_acacia_wood: [Object],
#       stripped_dark_oak_wood: [Object],
#       stripped_mangrove_wood: [Object],
#       oak_leaves: [Object],
#       spruce_leaves: [Object],
#       birch_leaves: [Object],
#       jungle_leaves: [Object],
#       acacia_leaves: [Object],
#       dark_oak_leaves: [Object],
#       mangrove_leaves: [Object],
#       azalea_leaves: [Object],
#       flowering_azalea_leaves: [Object],
#       sponge: [Object],
#       wet_sponge: [Object],
#       glass: [Object],
#       lapis_ore: [Object],
#       deepslate_lapis_ore: [Object],
#       lapis_block: [Object],
#       dispenser: [Object],
#       sandstone: [Object],
#       chiseled_sandstone: [Object],
#       cut_sandstone: [Object],
#       note_block: [Object],
#       white_bed: [Object],
#       orange_bed: [Object],
#       magenta_bed: [Object],
#       light_blue_bed: [Object],
#       yellow_bed: [Object],
#       lime_bed: [Object],
#       pink_bed: [Object],
#       gray_bed: [Object],
#       light_gray_bed: [Object],
#       cyan_bed: [Object],
#       purple_bed: [Object],
#       blue_bed: [Object],
#       brown_bed: [Object],
#       green_bed: [Object],
#       red_bed: [Object],
#       black_bed: [Object],
#       powered_rail: [Object],
#       detector_rail: [Object],
#       sticky_piston: [Object],
#       cobweb: [Object],
#       grass: [Object],
#       fern: [Object],
#       dead_bush: [Object],
#       seagrass: [Object],
#       tall_seagrass: [Object],
#       piston: [Object],
#       piston_head: [Object],
#       white_wool: [Object],
#       orange_wool: [Object],
#       magenta_wool: [Object],
#       light_blue_wool: [Object],
#       yellow_wool: [Object],
#       lime_wool: [Object],
#       pink_wool: [Object],
#       gray_wool: [Object],
#       light_gray_wool: [Object],
#       cyan_wool: [Object],
#       purple_wool: [Object],
#       blue_wool: [Object],
#       brown_wool: [Object],
#       green_wool: [Object],
#       red_wool: [Object],
#       black_wool: [Object],
#       moving_piston: [Object],
#       dandelion: [Object],
#       poppy: [Object],
#       blue_orchid: [Object],
#       allium: [Object],
#       azure_bluet: [Object],
#       red_tulip: [Object],
#       orange_tulip: [Object],
#       white_tulip: [Object],
#       pink_tulip: [Object],
#       oxeye_daisy: [Object],
#       cornflower: [Object],
#       wither_rose: [Object],
#       lily_of_the_valley: [Object],
#       brown_mushroom: [Object],
#       red_mushroom: [Object],
#       gold_block: [Object],
#       iron_block: [Object],
#       bricks: [Object],
#       tnt: [Object],
#       bookshelf: [Object],
#       mossy_cobblestone: [Object],
#       obsidian: [Object],
#       torch: [Object],
#       wall_torch: [Object],
#       fire: [Object],
#       soul_fire: [Object],
#       spawner: [Object],
#       oak_stairs: [Object],
#       chest: [Object],
#       redstone_wire: [Object],
#       diamond_ore: [Object],
#       deepslate_diamond_ore: [Object],
#       diamond_block: [Object],
#       crafting_table: [Object],
#       wheat: [Object],
#       farmland: [Object],
#       furnace: [Object],
#       oak_sign: [Object],
#       spruce_sign: [Object],
#       birch_sign: [Object],
#       acacia_sign: [Object],
#       jungle_sign: [Object],
#       dark_oak_sign: [Object],
#       mangrove_sign: [Object],
#       oak_door: [Object],
#       ladder: [Object],
#       rail: [Object],
#       cobblestone_stairs: [Object],
#       oak_wall_sign: [Object],
#       spruce_wall_sign: [Object],
#       birch_wall_sign: [Object],
#       acacia_wall_sign: [Object],
#       jungle_wall_sign: [Object],
#       dark_oak_wall_sign: [Object],
#       mangrove_wall_sign: [Object],
#       lever: [Object],
#       stone_pressure_plate: [Object],
#       iron_door: [Object],
#       oak_pressure_plate: [Object],
#       spruce_pressure_plate: [Object],
#       birch_pressure_plate: [Object],
#       jungle_pressure_plate: [Object],
#       acacia_pressure_plate: [Object],
#       dark_oak_pressure_plate: [Object],
#       mangrove_pressure_plate: [Object],
#       redstone_ore: [Object],
#       deepslate_redstone_ore: [Object],
#       redstone_torch: [Object],
#       redstone_wall_torch: [Object],
#       stone_button: [Object],
#       snow: [Object],
#       ice: [Object],
#       snow_block: [Object],
#       cactus: [Object],
#       clay: [Object],
#       sugar_cane: [Object],
#       jukebox: [Object],
#       oak_fence: [Object],
#       pumpkin: [Object],
#       netherrack: [Object],
#       soul_sand: [Object],
#       soul_soil: [Object],
#       basalt: [Object],
#       polished_basalt: [Object],
#       soul_torch: [Object],
#       soul_wall_torch: [Object],
#       glowstone: [Object],
#       nether_portal: [Object],
#       carved_pumpkin: [Object],
#       jack_o_lantern: [Object],
#       cake: [Object],
#       repeater: [Object],
#       white_stained_glass: [Object],
#       orange_stained_glass: [Object],
#       magenta_stained_glass: [Object],
#       light_blue_stained_glass: [Object],
#       yellow_stained_glass: [Object],
#       lime_stained_glass: [Object],
#       pink_stained_glass: [Object],
#       gray_stained_glass: [Object],
#       light_gray_stained_glass: [Object],
#       cyan_stained_glass: [Object],
#       purple_stained_glass: [Object],
#       blue_stained_glass: [Object],
#       brown_stained_glass: [Object],
#       green_stained_glass: [Object],
#       red_stained_glass: [Object],
#       black_stained_glass: [Object],
#       oak_trapdoor: [Object],
#       spruce_trapdoor: [Object],
#       birch_trapdoor: [Object],
#       jungle_trapdoor: [Object],
#       acacia_trapdoor: [Object],
#       dark_oak_trapdoor: [Object],
#       mangrove_trapdoor: [Object],
#       stone_bricks: [Object],
#       mossy_stone_bricks: [Object],
#       cracked_stone_bricks: [Object],
#       chiseled_stone_bricks: [Object],
#       packed_mud: [Object],
#       mud_bricks: [Object],
#       infested_stone: [Object],
#       infested_cobblestone: [Object],
#       infested_stone_bricks: [Object],
#       infested_mossy_stone_bricks: [Object],
#       infested_cracked_stone_bricks: [Object],
#       infested_chiseled_stone_bricks: [Object],
#       brown_mushroom_block: [Object],
#       red_mushroom_block: [Object],
#       mushroom_stem: [Object],
#       iron_bars: [Object],
#       chain: [Object],
#       glass_pane: [Object],
#       melon: [Object],
#       attached_pumpkin_stem: [Object],
#       attached_melon_stem: [Object],
#       pumpkin_stem: [Object],
#       melon_stem: [Object],
#       vine: [Object],
#       glow_lichen: [Object],
#       oak_fence_gate: [Object],
#       brick_stairs: [Object],
#       stone_brick_stairs: [Object],
#       mud_brick_stairs: [Object],
#       mycelium: [Object],
#       lily_pad: [Object],
#       nether_bricks: [Object],
#       nether_brick_fence: [Object],
#       nether_brick_stairs: [Object],
#       nether_wart: [Object],
#       enchanting_table: [Object],
#       brewing_stand: [Object],
#       cauldron: [Object],
#       water_cauldron: [Object],
#       lava_cauldron: [Object],
#       powder_snow_cauldron: [Object],
#       end_portal: [Object],
#       end_portal_frame: [Object],
#       end_stone: [Object],
#       dragon_egg: [Object],
#       redstone_lamp: [Object],
#       cocoa: [Object],
#       sandstone_stairs: [Object],
#       emerald_ore: [Object],
#       deepslate_emerald_ore: [Object],
#       ender_chest: [Object],
#       tripwire_hook: [Object],
#       tripwire: [Object],
#       emerald_block: [Object],
#       spruce_stairs: [Object],
#       birch_stairs: [Object],
#       jungle_stairs: [Object],
#       command_block: [Object],
#       beacon: [Object],
#       cobblestone_wall: [Object],
#       mossy_cobblestone_wall: [Object],
#       flower_pot: [Object],
#       potted_oak_sapling: [Object],
#       potted_spruce_sapling: [Object],
#       potted_birch_sapling: [Object],
#       potted_jungle_sapling: [Object],
#       potted_acacia_sapling: [Object],
#       potted_dark_oak_sapling: [Object],
#       potted_mangrove_propagule: [Object],
#       potted_fern: [Object],
#       potted_dandelion: [Object],
#       potted_poppy: [Object],
#       potted_blue_orchid: [Object],
#       potted_allium: [Object],
#       potted_azure_bluet: [Object],
#       potted_red_tulip: [Object],
#       potted_orange_tulip: [Object],
#       potted_white_tulip: [Object],
#       potted_pink_tulip: [Object],
#       potted_oxeye_daisy: [Object],
#       potted_cornflower: [Object],
#       potted_lily_of_the_valley: [Object],
#       potted_wither_rose: [Object],
#       potted_red_mushroom: [Object],
#       potted_brown_mushroom: [Object],
#       potted_dead_bush: [Object],
#       potted_cactus: [Object],
#       carrots: [Object],
#       potatoes: [Object],
#       oak_button: [Object],
#       spruce_button: [Object],
#       birch_button: [Object],
#       jungle_button: [Object],
#       acacia_button: [Object],
#       dark_oak_button: [Object],
#       mangrove_button: [Object],
#       skeleton_skull: [Object],
#       skeleton_wall_skull: [Object],
#       wither_skeleton_skull: [Object],
#       wither_skeleton_wall_skull: [Object],
#       zombie_head: [Object],
#       zombie_wall_head: [Object],
#       player_head: [Object],
#       player_wall_head: [Object],
#       creeper_head: [Object],
#       creeper_wall_head: [Object],
#       dragon_head: [Object],
#       dragon_wall_head: [Object],
#       anvil: [Object],
#       chipped_anvil: [Object],
#       damaged_anvil: [Object],
#       trapped_chest: [Object],
#       light_weighted_pressure_plate: [Object],
#       heavy_weighted_pressure_plate: [Object],
#       comparator: [Object],
#       daylight_detector: [Object],
#       redstone_block: [Object],
#       nether_quartz_ore: [Object],
#       hopper: [Object],
#       quartz_block: [Object],
#       chiseled_quartz_block: [Object],
#       quartz_pillar: [Object],
#       quartz_stairs: [Object],
#       activator_rail: [Object],
#       dropper: [Object],
#       white_terracotta: [Object],
#       orange_terracotta: [Object],
#       magenta_terracotta: [Object],
#       light_blue_terracotta: [Object],
#       yellow_terracotta: [Object],
#       lime_terracotta: [Object],
#       pink_terracotta: [Object],
#       gray_terracotta: [Object],
#       light_gray_terracotta: [Object],
#       cyan_terracotta: [Object],
#       purple_terracotta: [Object],
#       blue_terracotta: [Object],
#       brown_terracotta: [Object],
#       green_terracotta: [Object],
#       red_terracotta: [Object],
#       black_terracotta: [Object],
#       white_stained_glass_pane: [Object],
#       orange_stained_glass_pane: [Object],
#       magenta_stained_glass_pane: [Object],
#       light_blue_stained_glass_pane: [Object],
#       yellow_stained_glass_pane: [Object],
#       lime_stained_glass_pane: [Object],
#       pink_stained_glass_pane: [Object],
#       gray_stained_glass_pane: [Object],
#       light_gray_stained_glass_pane: [Object],
#       cyan_stained_glass_pane: [Object],
#       purple_stained_glass_pane: [Object],
#       blue_stained_glass_pane: [Object],
#       brown_stained_glass_pane: [Object],
#       green_stained_glass_pane: [Object],
#       red_stained_glass_pane: [Object],
#       black_stained_glass_pane: [Object],
#       acacia_stairs: [Object],
#       dark_oak_stairs: [Object],
#       mangrove_stairs: [Object],
#       slime_block: [Object],
#       barrier: [Object],
#       light: [Object],
#       iron_trapdoor: [Object],
#       prismarine: [Object],
#       prismarine_bricks: [Object],
#       dark_prismarine: [Object],
#       prismarine_stairs: [Object],
#       prismarine_brick_stairs: [Object],
#       dark_prismarine_stairs: [Object],
#       prismarine_slab: [Object],
#       prismarine_brick_slab: [Object],
#       dark_prismarine_slab: [Object],
#       sea_lantern: [Object],
#       hay_block: [Object],
#       white_carpet: [Object],
#       orange_carpet: [Object],
#       magenta_carpet: [Object],
#       light_blue_carpet: [Object],
#       yellow_carpet: [Object],
#       lime_carpet: [Object],
#       pink_carpet: [Object],
#       gray_carpet: [Object],
#       light_gray_carpet: [Object],
#       cyan_carpet: [Object],
#       purple_carpet: [Object],
#       blue_carpet: [Object],
#       brown_carpet: [Object],
#       green_carpet: [Object],
#       red_carpet: [Object],
#       black_carpet: [Object],
#       terracotta: [Object],
#       coal_block: [Object],
#       packed_ice: [Object],
#       sunflower: [Object],
#       lilac: [Object],
#       rose_bush: [Object],
#       peony: [Object],
#       tall_grass: [Object],
#       large_fern: [Object],
#       white_banner: [Object],
#       orange_banner: [Object],
#       magenta_banner: [Object],
#       light_blue_banner: [Object],
#       yellow_banner: [Object],
#       lime_banner: [Object],
#       pink_banner: [Object],
#       gray_banner: [Object],
#       light_gray_banner: [Object],
#       cyan_banner: [Object],
#       purple_banner: [Object],
#       blue_banner: [Object],
#       brown_banner: [Object],
#       green_banner: [Object],
#       red_banner: [Object],
#       black_banner: [Object],
#       white_wall_banner: [Object],
#       orange_wall_banner: [Object],
#       magenta_wall_banner: [Object],
#       light_blue_wall_banner: [Object],
#       yellow_wall_banner: [Object],
#       lime_wall_banner: [Object],
#       pink_wall_banner: [Object],
#       gray_wall_banner: [Object],
#       light_gray_wall_banner: [Object],
#       cyan_wall_banner: [Object],
#       purple_wall_banner: [Object],
#       blue_wall_banner: [Object],
#       brown_wall_banner: [Object],
#       green_wall_banner: [Object],
#       red_wall_banner: [Object],
#       black_wall_banner: [Object],
#       red_sandstone: [Object],
#       chiseled_red_sandstone: [Object],
#       cut_red_sandstone: [Object],
#       red_sandstone_stairs: [Object],
#       oak_slab: [Object],
#       spruce_slab: [Object],
#       birch_slab: [Object],
#       jungle_slab: [Object],
#       acacia_slab: [Object],
#       dark_oak_slab: [Object],
#       mangrove_slab: [Object],
#       stone_slab: [Object],
#       smooth_stone_slab: [Object],
#       sandstone_slab: [Object],
#       cut_sandstone_slab: [Object],
#       petrified_oak_slab: [Object],
#       cobblestone_slab: [Object],
#       brick_slab: [Object],
#       stone_brick_slab: [Object],
#       mud_brick_slab: [Object],
#       nether_brick_slab: [Object],
#       quartz_slab: [Object],
#       red_sandstone_slab: [Object],
#       cut_red_sandstone_slab: [Object],
#       purpur_slab: [Object],
#       smooth_stone: [Object],
#       smooth_sandstone: [Object],
#       smooth_quartz: [Object],
#       smooth_red_sandstone: [Object],
#       spruce_fence_gate: [Object],
#       birch_fence_gate: [Object],
#       jungle_fence_gate: [Object],
#       acacia_fence_gate: [Object],
#       dark_oak_fence_gate: [Object],
#       mangrove_fence_gate: [Object],
#       spruce_fence: [Object],
#       birch_fence: [Object],
#       jungle_fence: [Object],
#       acacia_fence: [Object],
#       dark_oak_fence: [Object],
#       mangrove_fence: [Object],
#       spruce_door: [Object],
# ...
#       'entity.zoglin.attack': [Object],
#       'entity.zoglin.death': [Object],
#       'entity.zoglin.hurt': [Object],
#       'entity.zoglin.step': [Object],
#       'entity.zombie.ambient': [Object],
#       'entity.zombie.attack_wooden_door': [Object],
#       'entity.zombie.attack_iron_door': [Object],
#       'entity.zombie.break_wooden_door': [Object],
#       'entity.zombie.converted_to_drowned': [Object],
#       'entity.zombie.death': [Object],
#       'entity.zombie.destroy_egg': [Object],
#       'entity.zombie_horse.ambient': [Object],
#       'entity.zombie_horse.death': [Object],
#       'entity.zombie_horse.hurt': [Object],
#       'entity.zombie.hurt': [Object],
#       'entity.zombie.infect': [Object],
#       'entity.zombified_piglin.ambient': [Object],
#       'entity.zombified_piglin.angry': [Object],
#       'entity.zombified_piglin.death': [Object],
#       'entity.zombified_piglin.hurt': [Object],
#       'entity.zombie.step': [Object],
#       'entity.zombie_villager.ambient': [Object],
#       'entity.zombie_villager.converted': [Object],
#       'entity.zombie_villager.cure': [Object],
#       'entity.zombie_villager.death': [Object],
#       'entity.zombie_villager.hurt': [Object],
#       'entity.zombie_villager.step': [Object]
#     },
#     soundsArray: [
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object], [Object], [Object],
#       [Object], [Object], [Object], [Object],
#       ... 1221 more items
#     ],
#     type: 'pc',
#     isNewerOrEqualTo: [Function (anonymous)],
#     isOlderThan: [Function (anonymous)],
#     supportFeature: [Function (anonymous)],
#     loadDimensionCodec: [Function: loadDimensionCodec],
#     writeDimensionCodec: [Function: writeDimensionCodec],
#     chatFormattingById: {
#       '0': [Object],
#       '1': [Object],
#       '2': [Object],
#       '3': [Object],
#       '4': [Object],
#       '5': [Object],
#       '6': [Object]
#     },
#     chatFormattingByName: {
#       'minecraft:chat': [Object],
#       'minecraft:say_command': [Object],
#       'minecraft:msg_command_incoming': [Object],
#       'minecraft:msg_command_outgoing': [Object],
#       'minecraft:team_msg_command_incoming': [Object],
#       'minecraft:team_msg_command_outgoing': [Object],
#       'minecraft:emote_command': [Object]
#     },
#     dimensionsById: { '0': [Object], '1': [Object], '2': [Object], '3': [Object] },
#     dimensionsByName: {
#       overworld: [Object],
#       the_nether: [Object],
#       the_end: [Object],
#       overworld_caves: [Object]
#     }
#   },
#   protocolVersion: 760,
#   majorVersion: '1.19',
#   version: '1.19.2',
#   supportFeature: [Function (anonymous)],
#   isSleeping: false,
#   parseBedMetadata: [Function: parseBedMetadata],
#   wake: [AsyncFunction: wake],
#   sleep: [AsyncFunction: sleep],
#   isABed: [Function: isABed],
#   findBlocks: [Function (anonymous)],
#   updateSign: [Function (anonymous)],
#   _getDimensionName: [Function (anonymous)],
#   findBlock: [Function: findBlock],
#   canSeeBlock: [Function: canSeeBlock],
#   blockAt: [Function: blockAt],
#   _updateBlockState: [Function: updateBlockState],
#   waitForChunksToLoad: [AsyncFunction: waitForChunksToLoad],
#   writeBook: [AsyncFunction (anonymous)],
#   signBook: [AsyncFunction (anonymous)],
#   chatAddPattern: [Function (anonymous)],
#   addChatPatternSet: [Function (anonymous)],
#   addChatPattern: [Function (anonymous)],
#   removeChatPattern: [Function (anonymous)],
#   whisper: [Function (anonymous)],
#   chat: [Function (anonymous)],
#   tabComplete: [AsyncFunction: tabComplete],
#   awaitMessage: [Function: awaitMessage],
#   openContainer: [AsyncFunction: openContainer],
#   openChest: [AsyncFunction: openContainer],
#   openDispenser: [AsyncFunction: openContainer],
#   setCommandBlock: [Function: setCommandBlock],
#   craft: [AsyncFunction: craft],
#   recipesFor: [Function: recipesFor],
#   recipesAll: [Function: recipesAll],
#   creative: {
#     setInventorySlot: [AsyncFunction: setInventorySlot],
#     flyTo: [AsyncFunction: flyTo],
#     startFlying: [Function: startFlying],
#     stopFlying: [Function: stopFlying],
#     clearSlot: [Function: clearSlot],
#     clearInventory: [AsyncFunction: clearInventory]
#   },
#   targetDigBlock: null,
#   targetDigFace: null,
#   lastDigTime: null,
#   dig: [AsyncFunction: dig],
#   stopDigging: [Function: noop],
#   canDigBlock: [Function: canDigBlock],
#   digTime: [Function: digTime],
#   openEnchantmentTable: [AsyncFunction: openEnchantmentTable],
#   findPlayers: [Function (anonymous)],
#   findPlayer: [Function (anonymous)],
#   players: {
#     follow_bot: {
#       username: 'follow_bot',
#       ping: 0,
#       uuid: 'c3d8700c-1e48-3e5a-9e0e-428d816d58cf',
#       displayName: [ChatMessage],
#       skinData: undefined,
#       profileKeys: null,
#       entity: [Entity],
#       gamemode: 0
#     },
#     relilau: {
#       username: 'relilau',
#       ping: 0,
#       uuid: 'd29f9ccf-af22-33ca-af51-83437fabf195',
#       displayName: [ChatMessage],
#       skinData: undefined,
#       profileKeys: null,
#       entity: undefined
#     }
#   },
#   uuidToUsername: {
#     'c3d8700c-1e48-3e5a-9e0e-428d816d58cf': 'follow_bot',
#     'd29f9ccf-af22-33ca-af51-83437fabf195': 'relilau'
#   },
#   entities: {
#     '1086': Entity {
#       _events: [Object: null prototype] {},
#       _eventsCount: 0,
#       _maxListeners: undefined,
#       id: 1086,
#       position: [Vec3],
#       velocity: [Vec3],
#       yaw: 3.141592653589793,
#       pitch: 0,
#       onGround: false,
#       height: 1.62,
#       width: 0,
#       effects: {},
#       equipment: [Array],
#       isValid: true,
#       metadata: [],
#       username: 'follow_bot',
#       type: 'player',
#       name: 'player',
#       [Symbol(shapeMode)]: false,
#       [Symbol(kCapture)]: false
#     }
#   },
#   _playerFromUUID: [Function (anonymous)],
#   nearestEntity: [Function (anonymous)],
#   fireworkRocketDuration: 0,
#   swingArm: [Function: swingArm],
#   attack: [Function: attack],
#   mount: [Function: mount],
#   dismount: [Function: dismount],
#   useOn: [Function: useOn],
#   moveVehicle: [Function: moveVehicle],
#   experience: { level: null, points: null, progress: null },
#   getExplosionDamages: [Function (anonymous)],
#   fish: [AsyncFunction: fish],
#   openFurnace: [AsyncFunction: openFurnace],
#   game: {
#     levelType: 'default',
#     hardcore: false,
#     gameMode: 'survival',
#     dimension: 'overworld',
#     minY: -64,
#     height: 384,
#     maxPlayers: 20,
#     enableRespawnScreen: true,
#     serverViewDistance: 10,
#     serverBrand: 'fabric',
#     difficulty: 'peaceful'
#   },
#   isAlive: true,
#   respawn: [Function: respawn],
#   quickBarSlot: 0,
#   inventory: Window {
#     _events: [Object: null prototype] {},
#     _eventsCount: 0,
#     _maxListeners: undefined,
#     acceptOutsideWindowClick: [Function: acceptClick],
#     acceptInventoryClick: [Function: acceptClick],
#     acceptNonInventorySwapAreaClick: [Function: acceptClick],
#     acceptSwapAreaLeftClick: [Function: acceptClick],
#     acceptSwapAreaRightClick: [Function: acceptClick],
#     acceptCraftingClick: [Function: acceptClick],
#     id: 0,
#     type: 'minecraft:inventory',
#     title: 'Inventory',
#     slots: [
#       null, null, null, null, null, null,
#       null, null, null, null, null, null,
#       null, null, null, null, null, null,
#       null, null, null, null, null, null,
#       null, null, null, null, null, null,
#       null, null, null, null, null, null,
#       null, null, null, null, null, null,
#       null, null, null, null
#     ],
#     inventoryStart: 9,
#     inventoryEnd: 45,
#     hotbarStart: 36,
#     craftingResultSlot: 0,
#     requiresConfirmation: true,
#     selectedItem: null,
#     [Symbol(shapeMode)]: false,
#     [Symbol(kCapture)]: false
#   },
#   currentWindow: null,
#   usingHeldItem: false,
#   activateBlock: [AsyncFunction: activateBlock],
#   activateEntity: [AsyncFunction: activateEntity],
#   activateEntityAt: [AsyncFunction: activateEntityAt],
#   consume: [AsyncFunction: consume],
#   activateItem: [Function: activateItem],
#   deactivateItem: [Function: deactivateItem],
#   clickWindow: [AsyncFunction: clickWindow],
#   putSelectedItemRange: [AsyncFunction: putSelectedItemRange],
#   putAway: [AsyncFunction: putAway],
#   closeWindow: [Function: closeWindow],
#   transfer: [AsyncFunction: transfer],
#   openBlock: [AsyncFunction: openBlock],
#   openEntity: [AsyncFunction: openEntity],
#   moveSlotItem: [AsyncFunction: moveSlotItem],
#   updateHeldItem: [Function: updateHeldItem],
#   quit: [Function (anonymous)],
#   jumpQueued: false,
#   jumpTicks: 0,
#   physicsEnabled: true,
#   physics: {
#     gravity: 0.08,
#     airdrag: 0.9800000190734863,
#     yawSpeed: 3,
#     pitchSpeed: 3,
#     playerSpeed: 0.1,
#     sprintSpeed: 0.3,
#     sneakSpeed: 0.3,
#     stepHeight: 0.6,
#     negligeableVelocity: 0.003,
#     soulsandSpeed: 0.4,
#     honeyblockSpeed: 0.4,
#     honeyblockJumpSpeed: 0.4,
#     ladderMaxSpeed: 0.15,
#     ladderClimbSpeed: 0.2,
#     playerHalfWidth: 0.3,
#     playerHeight: 1.8,
#     waterInertia: 0.8,
#     lavaInertia: 0.5,
#     liquidAcceleration: 0.02,
#     airborneInertia: 0.91,
#     airborneAcceleration: 0.02,
#     defaultSlipperiness: 0.6,
#     outOfLiquidImpulse: 0.3,
#     autojumpCooldown: 10,
#     bubbleColumnSurfaceDrag: { down: 0.03, maxDown: -0.9, up: 0.1, maxUp: 1.8 },
#     bubbleColumnDrag: { down: 0.03, maxDown: -0.3, up: 0.06, maxUp: 0.7 },
#     slowFalling: 0.125,
#     movementSpeedAttribute: 'generic.movement_speed',
#     sprintingUUID: '662a6b8d-da3e-4c1c-8813-96ea6097278d',
#     waterGravity: 0.005,
#     lavaGravity: 0.02,
#     adjustPositionHeight: [Function (anonymous)],
#     simulatePlayer: [Function (anonymous)]
#   },
#   elytraFly: [AsyncFunction (anonymous)],
#   setControlState: [Function (anonymous)],
#   getControlState: [Function (anonymous)],
#   clearControlStates: [Function (anonymous)],
#   controlState: {},
#   look: [AsyncFunction (anonymous)],
#   lookAt: [AsyncFunction (anonymous)],
#   waitForTicks: [AsyncFunction (anonymous)],
#   placeBlock: [AsyncFunction: placeBlock],
#   _placeBlockWithOptions: [AsyncFunction: placeBlockWithOptions],
#   isRaining: false,
#   thunderState: 0,
#   rainState: 0,
#   blockInSight: [Function (anonymous)],
#   blockAtCursor: [Function (anonymous)],
#   entityAtCursor: [Function (anonymous)],
#   blockAtEntityCursor: [Function (anonymous)],
#   acceptResourcePack: [Function: acceptResourcePack],
#   denyResourcePack: [Function: denyResourcePack],
#   scoreboards: {},
#   scoreboard: { list: [Getter], sidebar: [Getter], belowName: [Getter] },
#   teams: {},
#   teamMap: {},
#   settings: {
#     chat: 'enabled',
#     colorsEnabled: true,
#     viewDistance: 'far',
#     difficulty: 2,
#     skinParts: {
#       showCape: true,
#       showJacket: true,
#       showLeftSleeve: true,
#       showRightSleeve: true,
#       showLeftPants: true,
#       showRightPants: true,
#       showHat: true
#     },
#     mainHand: 'right',
#     enableTextFiltering: false,
#     enableServerListing: true
#   },
#   setSettings: [Function: setSettings],
#   equip: [AsyncFunction: equip],
#   unequip: [AsyncFunction: unequip],
#   toss: [AsyncFunction: toss],
#   tossStack: [AsyncFunction: tossStack],
#   setQuickBarSlot: [Function: setQuickBarSlot],
#   getEquipmentDestSlot: [Function: getDestSlot],
#   simpleClick: {
#     leftMouse: [Function: leftMouse],
#     rightMouse: [Function: rightMouse]
#   },
#   QUICK_BAR_START: 36,
#   spawnPoint: Vec3 { x: 0, y: 0, z: 0 },
#   tablist: {
#     header: ChatMessage {
#       json: [Object],
#       warn: [Function],
#       text: '',
#       bold: undefined,
#       italic: undefined,
#       underlined: undefined,
#       strikethrough: undefined,
#       obfuscated: undefined,
#       color: undefined
#     },
#     footer: ChatMessage {
#       json: [Object],
#       warn: [Function],
#       text: '',
#       bold: undefined,
#       italic: undefined,
#       underlined: undefined,
#       strikethrough: undefined,
#       obfuscated: undefined,
#       color: undefined
#     }
#   },
#   time: {
#     doDaylightCycle: null,
#     bigTime: null,
#     time: null,
#     timeOfDay: null,
#     day: null,
#     isDay: null,
#     moonPhase: null,
#     bigAge: null,
#     age: null
#   },
#   openVillager: [AsyncFunction: openVillager],
#   trade: [AsyncFunction: trade],
#   openAnvil: [AsyncFunction: openAnvil],
#   placeEntity: [AsyncFunction: placeEntity],
#   _placeEntityWithOptions: [AsyncFunction: placeEntityWithOptions],
#   _genericPlace: [AsyncFunction: _genericPlace],
#   pathfinder: {
#     thinkTimeout: 5000,
#     tickTimeout: 40,
#     searchRadius: -1,
#     enablePathShortcut: false,
#     LOSWhenPlacingBlocks: true,
#     bestHarvestTool: [Function (anonymous)],
#     getPathTo: [Function (anonymous)],
#     getPathFromTo: [GeneratorFunction (anonymous)],
#     setGoal: [Function (anonymous)],
#     setMovements: [Function (anonymous)],
#     isMoving: [Function (anonymous)],
#     isMining: [Function (anonymous)],
#     isBuilding: [Function (anonymous)],
#     goto: [Function (anonymous)],
#     stop: [Function (anonymous)]
#   },
#   world: <ref *1> WorldSync {
#     _events: [Object: null prototype] {
#       blockUpdate: [Function (anonymous)],
#       chunkColumnLoad: [Function (anonymous)],
#       chunkColumnUnload: [Function (anonymous)]
#     },
#     _eventsCount: 3,
#     _maxListeners: undefined,
#     async: World {
#       _events: [Object: null prototype] {},
#       _eventsCount: 0,
#       _maxListeners: undefined,
#       savingQueue: Map(0) {},
#       unloadQueue: Map(0) {},
#       finishedSaving: [Promise],
#       currentlySaving: false,
#       columns: [Object],
#       chunkGenerator: null,
#       storageProvider: null,
#       savingInterval: 1000,
#       sync: [Circular *1],
#       [Symbol(shapeMode)]: false,
#       [Symbol(kCapture)]: false
#     },
#     [Symbol(shapeMode)]: false,
#     [Symbol(kCapture)]: false
#   },
#   entity: Entity {
#     _events: [Object: null prototype] {},
#     _eventsCount: 0,
#     _maxListeners: undefined,
#     id: 1086,
#     position: Vec3 { x: 56.5, y: 95, z: 177.5 },
#     velocity: Vec3 { x: 0, y: 0, z: 0 },
#     yaw: 3.141592653589793,
#     pitch: 0,
#     onGround: false,
#     height: 1.62,
#     width: 0,
#     effects: {},
#     equipment: [ <5 empty items> ],
#     isValid: true,
#     metadata: [],
#     username: 'follow_bot',
#     type: 'player',
#     name: 'player',
#     [Symbol(shapeMode)]: false,
#     [Symbol(kCapture)]: false
#   },
#   username: 'follow_bot',
#   player: {
#     username: 'follow_bot',
#     ping: 0,
#     uuid: 'c3d8700c-1e48-3e5a-9e0e-428d816d58cf',
#     displayName: ChatMessage {
#       json: [Object],
#       warn: [Function],
#       text: '',
#       extra: [Array],
#       bold: undefined,
#       italic: undefined,
#       underlined: undefined,
#       strikethrough: undefined,
#       obfuscated: undefined,
#       color: undefined
#     },
#     skinData: undefined,
#     profileKeys: null,
#     entity: Entity {
#       _events: [Object: null prototype] {},
#       _eventsCount: 0,
#       _maxListeners: undefined,
#       id: 1086,
#       position: [Vec3],
#       velocity: [Vec3],
#       yaw: 3.141592653589793,
#       pitch: 0,
#       onGround: false,
#       height: 1.62,
#       width: 0,
#       effects: {},
#       equipment: [Array],
#       isValid: true,
#       metadata: [],
#       username: 'follow_bot',
#       type: 'player',
#       name: 'player',
#       [Symbol(shapeMode)]: false,
#       [Symbol(kCapture)]: false
#     },
#     gamemode: 0
#   },
#   [Symbol(shapeMode)]: false,
#   [Symbol(kCapture)]: false
# }

# %% [markdown]
# ## Exiting the bot
#
# Once you're done, you can call `bot.quit()` or `bot.end()` to disconnect and stop the bot.

# %%
bot.quit()

# %% [markdown]
# ## Read more
#
# * **API** - https://github.com/PrismarineJS/mineflayer/blob/master/docs/api.md
# * **Type Definitions** - https://github.com/PrismarineJS/mineflayer/blob/master/index.d.ts
# * FAQ - https://github.com/PrismarineJS/mineflayer/blob/master/docs/FAQ.md
# * JS tutorial - https://github.com/PrismarineJS/mineflayer/blob/master/docs/tutorial.md
